# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.datasets import imdb

# %%
## Load from the IMDB dataset the word index

word_index = imdb.get_word_index()
reverse_word_index = {value : key for key, value in word_index.items()}
reverse_word_index
# Out:
# {34701: 'fawn',
#  52006: 'tsukino',
#  52007: 'nunnery',
#  16816: 'sonja',
#  63951: 'vani',
#  1408: 'woods',
#  16115: 'spiders',
#  2345: 'hanging',
#  2289: 'woody',
#  52008: 'trawling',
#  52009: "hold's",
#  11307: 'comically',
#  40830: 'localized',
#  30568: 'disobeying',
#  52010: "'royale",
#  40831: "harpo's",
#  52011: 'canet',
#  19313: 'aileen',
#  52012: 'acurately',
#  52013: "diplomat's",
#  25242: 'rickman',
#  6746: 'arranged',
#  52014: 'rumbustious',
#  52015: 'familiarness',
#  52016: "spider'",
#  68804: 'hahahah',
#  52017: "wood'",
#  40833: 'transvestism',
#  34702: "hangin'",
#  2338: 'bringing',
#  40834: 'seamier',
#  34703: 'wooded',
#  52018: 'bravora',
#  16817: 'grueling',
#  1636: 'wooden',
#  16818: 'wednesday',
#  52019: "'prix",
#  34704: 'altagracia',
#  52020: 'circuitry',
#  11585: 'crotch',
#  57766: 'busybody',
#  52021: "tart'n'tangy",
#  14129: 'burgade',
#  52023: 'thrace',
#  11038: "tom's",
#  52025: 'snuggles',
# ...

# %%
model = load_model("rnn_imdb.h5")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 500, 128)          1280000
#
#  simple_rnn (SimpleRNN)      (None, 128)               32896
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 1,313,025
# Trainable params: 1,313,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[-0.00685744,  0.02325961, -0.01951289, ...,  0.00447311,
#          -0.02958499, -0.03442423],
#         [-0.03663779,  0.03566552,  0.00516698, ..., -0.0286066 ,
#           0.04805469,  0.03621512],
#         [ 0.03850498, -0.03064163, -0.05539774, ...,  0.04607882,
#           0.00675258, -0.04004423],
#         ...,
#         [ 0.00757376,  0.00125584,  0.00673321, ...,  0.02185685,
#          -0.0308824 ,  0.00078649],
#         [ 0.00811488,  0.1380775 ,  0.00268101, ..., -0.06409582,
#          -0.07669354, -0.01966254],
#         [ 0.03827   , -0.05369082,  0.00872334, ...,  0.10640372,
#           0.06270587, -0.01293693]], dtype=float32),
#  array([[-0.13438062,  0.11600894,  0.07685056, ...,  0.03821624,
#           0.03949114, -0.15381677],
#         [-0.11261089,  0.01837841, -0.01100595, ...,  0.1357535 ,
#           0.06757665,  0.00427343],
#         [-0.11545871, -0.07293756, -0.04543573, ...,  0.07324901,
#          -0.09359636, -0.09475245],
# ...

# %%
### HELPER FUNCTION TO DECODE THE REVIEW

def decode_review(encoded_review):
    return " ".join([reverse_word_index.get(i-3,"?") for i in encoded_review])

### HELPER FUNCTION TO PREPROCESS THE USER INPUT

def preprocess_text(text):
    words = text.lower().split()
    encoded_review = [word_index.get(word, 2) + 3 for word in words]
    padded_review = sequence.pad_sequences([encoded_review], maxlen=500)
    return padded_review

# %%
### PREDICTION FUNCTION

def predict_sentiment(review):
    preprocessed_input = preprocess_text(review)

    prediction = model.predict(preprocessed_input)
    
    sentiment = "POSITIVE" if prediction[0][0] >= 0.5 else "NEGATIVE"
    
    return sentiment,prediction[0][0]

# %%
example_review = "This movie was absolutely amazing! I loved it so much. The plot was thrilling, and the acting was superb. I highly recommend it to anyone looking for a good time at the movies."
sentiment, sentiment_score = predict_sentiment(example_review)

print(f"Review: {example_review}")
print(f"Sentiment: {sentiment}")
print(f"Sentiment Score: {sentiment_score}")
# Out:
# 1/1 [==============================] - 0s 101ms/step
# Review: This movie was absolutely amazing! I loved it so much. The plot was thrilling, and the acting was superb. I highly recommend it to anyone looking for a good time at the movies.
# Sentiment: POSITIVE
# Sentiment Score: 0.9422932267189026
